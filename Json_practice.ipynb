# %%
import pandas as pd 
import json
import numpy as np
from pandas.io.json import json_normalize

# %%
#json.load((open('//Users//zoegong//Downloads//data_wrangling_json//data//world_bank_projects.json')))
#sample_json_df = pd.read_json('data/world_bank_projects_less.json')
df=pd.read_json('//Users//zoegong//Downloads//data_wrangling_json//data//world_bank_projects.json',lines=False)
df
# Out:
#                                                 sector supplementprojectflg  \
# 0    [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1    [{'Name': 'Public administration- Other social...                    N
# 2    [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
# 3                  [{'Name': 'Other social services'}]                    N
# 4    [{'Name': 'General industry and trade sector'}...                    N
# ..                                                 ...                  ...
# 495  [{'Name': 'General agriculture, fishing and fo...                    N
# 496  [{'Name': 'Central government administration'}...                    N
# 497  [{'Name': 'Irrigation and drainage'}, {'Name':...                    N
# 498  [{'Name': 'Agricultural extension and research...                    N
# 499  [{'Name': 'Urban Transport'}, {'Name': 'Public...                    N
#
#     projectfinancialtype prodline  \
# ...

# %%
df.sort_values('idacommamt',ascending=False)['countryname'][0:10]
# Out:
# 463    Federal Democratic Republic of Ethiopia
# 110            People's Republic of Bangladesh
# 476              Socialist Republic of Vietnam
# 340           Republic of the Union of Myanmar
# 461    Federal Democratic Republic of Ethiopia
# 288               Islamic Republic of Pakistan
# 108            People's Republic of Bangladesh
# 57                           Republic of India
# 65                                      Africa
# 465            People's Republic of Bangladesh
# Name: countryname, dtype: object

# %%
m=df['mjtheme_namecode'].value_counts(ascending=False)[0:10]
m
# Out:
# [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]                                                                                12
# [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]                                                                                                                                                        11
# [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]                                                                                                                                         8
# [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]                                                                                           6
# ...

# %%
pd.DataFrame(m).fillna(method='ffill')
# Out:
#                                                     mjtheme_namecode
# [{'code': '11', 'name': 'Environment and natura...                12
# [{'code': '8', 'name': 'Human development'}, {'...                11
# [{'code': '8', 'name': 'Human development'}, {'...                 8
# [{'code': '4', 'name': 'Financial and private s...                 6
# [{'code': '2', 'name': 'Public sector governanc...                 6
# [{'code': '8', 'name': 'Human development'}, {'...                 5
# [{'code': '8', 'name': 'Human development'}, {'...                 5
# [{'code': '11', 'name': 'Environment and natura...                 5
# [{'code': '11', 'name': 'Environment and natura...                 5
# [{'code': '4', 'name': 'Financial and private s...                 5
